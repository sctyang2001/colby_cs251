# %% [markdown]
# **YOUR NAME HERE**
#
# Fall 2021
#
# CS 251: Data Analysis and Visualization

# %% [markdown]
# # Lab 01b: Intro to Jupyter Notebook, NumPy and MatPlotLib
#
# ## Task 0: Intro to Jupyter Notebook
#
# ### Running Jupyter Notebook on your computer
#
# 1. Download the lab assignment, unzip it and move the `Lab01b` folder to your desired directory
# 2. Open terminal
# 3. run `jupyter notebook`
# 4. Browser opens with "Files" tab selected.
# 5. Open `Lab01b.ipynb` through the Jupyter Notebook by navigating through the directory system.
#
# ### Accessing Jupyter Notebook on jupyter.colby.edu
#
# 1. Mount your Personal Drive on `filer`
# 2. Download the lab assignment, unzip it and move the `Lab01b` folder to your personal directory
# 3. In your browser go to [https://jupyter.colby.edu](https://jupyter.colby.edu)
# 4. Login using your colby credentials
# 5. Open `Lab01b.ipynb` through the Jupyter Notebook by navigating through the directory system.
#
# ### Editing Jupyter Notebook Markdown cells
#
# 1. Update a Markdown cell [Markdown quick reference](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
#     1. Double click on "YOUR NAME HERE" at the top of the page
#     2. Replace "YOUR NAME HERE" with your first and last name
#     3. press Run or `Shift+Enter`
#
# <img src="images/bar.png" alt="heading"/>
#
# ***
#
# ## Task 1: Intro to NumPy
#
# ### 1a) Create a NumPy Array
#
# 1. Import 'test.csv' into a ndarray using [NumPy genfromtxt](https://numpy.org/devdocs/reference/generated/numpy.genfromtxt.html), [More info](https://numpy.org/devdocs/user/basics.io.genfromtxt.html)
# 2. Print data [printing arrays](https://numpy.org/doc/stable/user/quickstart.html#printing-arrays)

# %%
import numpy as np
ndArray = np.genfromtxt("data/test.csv", delimiter=",")
ndArray
# Out:
# array([[15., 16.,  4.,  5.],
#        [ 4., 10., 10.,  3.],
#        [10.,  4., 17., 12.],
#        [ 6., 12.,  1., 16.],
#        [14., 15.,  1., 12.],
#        [11., 15., 19.,  2.]])

# %% [markdown]
# ### 1b) Explore NumPy array
#
# #### Using the below links ↓ and NumPy documentation to complete the following tasks:
# [NumPy ndarray](https://numpy.org/devdocs/reference/arrays.ndarray.html)
# [Array indexing](https://numpy.org/devdocs/user/basics.indexing.html#basics-indexing)
#
# - Print the shape of the array from test.csv.
# - Print only the row with the index of 4 of the array from test.csv.
# - Print only the column with the index of 1 of the array from test.csv.
# - Use a single ndarray method to find the min of each column of the array from test.csv and print the result
# - Use a single ndarray method to find the max of each row of the array from test.csv and print the result
# - Use a single ndarray method to find the mean of each column of the array from test.csv and print the result
# - Use a single ndarray method to find the sum of each row of the array from test.csv and print the result
# - What is the shape of array2?
# - In one line use a ndarray method to convert array2 to a two dimensional array.

# %%
#array2 given
array2 = np.array([[[0], [2], [4]],[[1], [3], [5]]])
array2
# Out:
# array([[[0],
#         [2],
#         [4]],
#
#        [[1],
#         [3],
#         [5]]])

# %%
ndArray.shape
# Out:
# (6, 4)

# %%
print(ndArray[4])
# Out:
# [14. 15.  1. 12.]

# %%
print(ndArray[:,1])
# Out:
# [16. 10.  4. 12. 15. 15.]

# %%
print(ndArray.min(axis=0))
# Out:
# [4. 4. 1. 2.]

# %%
print(ndArray.max(axis=1))
# Out:
# [16. 10. 17. 16. 15. 19.]

# %%
print(ndArray.mean(axis=0))
# Out:
# [10.         12.          8.66666667  8.33333333]

# %%
print(ndArray.sum(axis=1))
# Out:
# [40. 27. 43. 35. 42. 47.]

# %%
array2.shape
# Out:
# (2, 3, 1)

# %%
array2.reshape(2,3)
# Out:
# array([[0, 2, 4],
#        [1, 3, 5]])

# %% [markdown]
# ***
#
# ## Task 2: MatPlotLib Basics
#
# ### 2a) Plot the data in a single plot
#
# Using the [MatPlotLib](https://matplotlib.org/) documentation, visualize the dataset with Matplotlib. All charts should include a title, axis labels and a legend when applicable.
#
# 1. Import `lab1.csv` into a ndarray using genfromtxt.
# 2. Set figure size to 5x5. [Figure reference](https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.figure.html)
# 2. Create a cartesian line graph of column 2 (index 2) on the X axis vs column 1 (index 1) on the Y axis using a red dashed line. [matplotlib.pyplot introduction](https://matplotlib.org/stable/tutorials/introductory/pyplot.html)
#     1. Include a title (Lab 1 data) and axis labels (column 1 and column 2).
#     2. Checkout [Controlling line properties](https://matplotlib.org/stable/tutorials/introductory/pyplot.html) for more information about setting [linestyle](https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html), [marker](https://matplotlib.org/stable/api/markers_api.html) and [color](https://matplotlib.org/stable/gallery/color/named_colors.html).

# %%
import matplotlib.pyplot as plt
import numpy as np

plotLab = np.genfromtxt("data/lab1.csv", delimiter=",")

# %%
plt.figure(figsize=(5,5))
plt.plot(plotLab[:,2],plotLab[:,1], 'r*')
plt.xlabel('column 2')
plt.ylabel('column 1')
plt.title('Lab 1 data')
plt.show()

# %% [markdown]
# ### 2b) Plot the data in multiple subplots
#
# Create 6 graphs in 2 columns and 3 rows using [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html).  \
# *Note: this can be done with a for loop*
#
# 1. Set figure size to 12x8. [Figure reference](https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.figure.html)
# 1. Row 1 is two subplots (a scatterplot and a line graph) of column 1 graphed on the x-axis VS column 0 graphed on the y-axis
# 2. Row 2 is two subplots (a scatterplot and a line graph) of column 2 (x-axis) VS column 1 (y-axis)
# 3. Row 3 is two subplots (a scatterplot and a line graph) of column 2 (x-axis) VS column 0 (y-axis)
# 4. Include a title (eg. column 1 vs column 2) and axis labels (eg. column 0) for each subplot.
# 5. To insure there is enough space between subplots use [subplots_adjust](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplots_adjust.html)

# %%
plt.figure(figsize=(12, 8))

plt.subplot(3, 2, 1)
plt.plot(plotLab[:,1],plotLab[:,0], 'r*')
plt.xlabel('column 1')
plt.ylabel('column 0')
plt.title('column 1 vs column 0')

plt.subplot(3, 2, 2)
plt.plot(plotLab[:,1],plotLab[:,0], 'y-')
plt.xlabel('column 1')
plt.ylabel('column 0')
plt.title('column 1 vs column 0')

plt.subplot(3, 2, 3)
plt.plot(plotLab[:,2],plotLab[:,1], 'b*')
plt.xlabel('column 2')
plt.ylabel('column 1')
plt.title('column 2 vs column 1')

plt.subplot(3, 2, 4)
plt.plot(plotLab[:,2],plotLab[:,1], 'p-')
plt.xlabel('column 2')
plt.ylabel('column 1')
plt.title('column 2 vs column 1')

plt.subplot(3, 2, 5)
plt.plot(plotLab[:,2],plotLab[:,0], 'r*')
plt.xlabel('column 2')
plt.ylabel('column 0')
plt.title('column 2 vs column 0')

plt.subplot(3, 2, 6)
plt.plot(plotLab[:,2],plotLab[:,0], 'g-')
plt.xlabel('column 2')
plt.ylabel('column 0')
plt.title('column 2 vs column 0')

plt.subplots_adjust(hspace = .5)

plt.show()

# %% [markdown]
# ### 2c) Analysis Question
# Which pairs of columns are easier to read as scatter plots and which are easier to read as line graphs?  Why?

# %% [markdown]
# Column 1 vs column 0 is easier to read as scatter plots, as they shows a clear pattern of numbers distribution. Column 2 vs column 1 and column 2 vs column 0 is easier to read as linear graphs as they connect disordered dots together to show a disciplined, more-obvious pattern.

# %% [markdown]
# ## 3) Submit the Lab on classroom
#
# On classroom, upload and submit the Lab01b ipython notebook when you have completed the Lab.
